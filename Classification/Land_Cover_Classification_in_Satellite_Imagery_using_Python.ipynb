# %% [markdown]
# <a href="https://colab.research.google.com/github/syamkakarla98/Satellite_Imagery_Analysis/blob/main/Classification/Land_Cover_Classification_in_Satellite_Imagery_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='tomato'>Land Cover Classification in Satellite Imagery using Python</font>

# %%
# !pip install earthpy gdal
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting earthpy
#   Using cached earthpy-0.9.4-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: matplotlib>=2.0.0 in ./.local/lib/python3.10/site-packages (from earthpy) (3.7.1)
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 14.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: requests in ./.local/lib/python3.10/site-packages (from earthpy) (2.32.3)
# Requirement already satisfied: geopandas in ./.local/lib/python3.10/site-packages (from earthpy) (0.13.2)
# Requirement already satisfied: numpy>=1.14.0 in ./.local/lib/python3.10/site-packages (from earthpy) (1.25.2)
# Requirement already satisfied: rasterio in ./.local/lib/python3.10/site-packages (from earthpy) (1.3.10)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->earthpy) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in ./.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->earthpy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->earthpy) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->earthpy) (2.4.7)
# Requirement already satisfied: pyproj>=3.0.1 in ./.local/lib/python3.10/site-packages (from geopandas->earthpy) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in ./.local/lib/python3.10/site-packages (from geopandas->earthpy) (2.0.4)
# Requirement already satisfied: fiona>=1.8.19 in ./.local/lib/python3.10/site-packages (from geopandas->earthpy) (1.9.6)
# Requirement already satisfied: pandas>=1.1.0 in ./.local/lib/python3.10/site-packages (from geopandas->earthpy) (2.0.3)
# Requirement already satisfied: cligj>=0.5 in ./.local/lib/python3.10/site-packages (from rasterio->earthpy) (0.7.2)
# Requirement already satisfied: click-plugins in ./.local/lib/python3.10/site-packages (from rasterio->earthpy) (1.1.1)
# Requirement already satisfied: click>=4.0 in /usr/lib/python3/dist-packages (from rasterio->earthpy) (8.0.3)
# Requirement already satisfied: affine in ./.local/lib/python3.10/site-packages (from rasterio->earthpy) (2.4.0)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from rasterio->earthpy) (2020.6.20)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from rasterio->earthpy) (59.6.0)
# Requirement already satisfied: attrs in ./.local/lib/python3.10/site-packages (from rasterio->earthpy) (23.2.0)
# Requirement already satisfied: snuggs>=1.4.1 in ./.local/lib/python3.10/site-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->earthpy) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests->earthpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->earthpy) (3.3)
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.6.18-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 KB 2.9 MB/s eta 0:00:00m eta 0:00:01
# Collecting imageio>=2.33
#   Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 KB 3.9 MB/s eta 0:00:000:00:01
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: networkx>=2.8 in ./.local/lib/python3.10/site-packages (from scikit-image->earthpy) (3.3)
# Requirement already satisfied: scipy>=1.9 in ./.local/lib/python3.10/site-packages (from scikit-image->earthpy) (1.14.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from fiona>=1.8.19->geopandas->earthpy) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.1.0->geopandas->earthpy) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in ./.local/lib/python3.10/site-packages (from pandas>=1.1.0->geopandas->earthpy) (2024.1)
# Installing collected packages: tifffile, lazy-loader, imageio, scikit-image, earthpy
# Successfully installed earthpy-0.9.4 imageio-2.34.2 lazy-loader-0.4 scikit-image-0.24.0 tifffile-2024.6.18

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Requirement already satisfied: packaging in ./.local/lib/python3.10/site-packages (from plotly) (24.1)
# Requirement already satisfied: tenacity>=6.2.0 in ./.local/lib/python3.10/site-packages (from plotly) (8.4.2)
# Installing collected packages: plotly
# Successfully installed plotly-5.22.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Modules

# %%
from glob import glob

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import rasterio as rio
from rasterio.plot import plotting_extent
from rasterio.plot import show
from rasterio.plot import reshape_as_raster, reshape_as_image

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

from scipy.io import loadmat
from sklearn.metrics import classification_report, accuracy_score

import plotly.graph_objects as go

np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'ignore', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %%
# %cd /content/drive/My Drive/Satellite_data
# Out:
# /content/drive/My Drive/Satellite_data

# %%
ls
# Out:
# Classification/  code/  Dimensionality_Reduction/  README.md
# Clustering/      Data/  LICENSE.txt

# %% [markdown]
# # Read Data

# %%
from glob import glob

# Correct path to match the directory structure
S_sentinel_bands = glob("Data/sundarbans_data/*B?*.tiff")

# Sort the file paths
S_sentinel_bands.sort()

# Print the list of file paths
print("Files found:", len(S_sentinel_bands))
print(S_sentinel_bands)
# Out:
# []

# %%
l = []
for i in S_sentinel_bands:
  with rio.open(i, 'r') as f:
    l.append(f.read(1))

# %%
arr_st = np.stack(l)

# %%
print(f'Height: {arr_st.shape[1]}\nWidth: {arr_st.shape[2]}\nBands: {arr_st.shape[0]}')
# Out:
# Height: 954
# Width: 298
# Bands: 12

# %% [markdown]
# # Visualize Data

# %% [markdown]
# ## Bands

# %%
ep.plot_bands(arr_st, cmap = 'gist_earth', figsize = (20, 12), cols = 6, cbar = False)
plt.show()

# %% [markdown]
# ## RGB Composite Image

# %%
rgb = ep.plot_rgb(arr_st, 
                  rgb=(3,2,1), 
                  figsize=(8, 10), 
                  # title='RGB Composite Image'
                  )

plt.show()

# %%
ep.plot_rgb(
    arr_st,
    rgb=(3, 2, 1),
    stretch=True,
    str_clip=0.2,
    figsize=(8, 10),
    # title="RGB Composite Image with Stretch Applied",
)

plt.show()

# %% [markdown]
# ## Data Distribution of Bands

# %%
colors = ['tomato', 'navy', 'MediumSpringGreen', 'lightblue', 'orange', 'blue',
          'maroon', 'purple', 'yellow', 'olive', 'brown', 'cyan']

ep.hist(arr_st, 
         colors = colors,
        title=[f'Band-{i}' for i in range(1, 13)], 
        cols=3, 
        alpha=0.5, 
        figsize = (12, 10)
        )

plt.show()

# %% [markdown]
# # Preprocessing

# %%
x = np.moveaxis(arr_st, 0, -1)
x.shape
# Out:
# (954, 298, 12)

# %%
from sklearn.preprocessing import StandardScaler

X_data = x.reshape(-1, 12)

scaler = StandardScaler().fit(X_data)

X_scaled = scaler.transform(X_data)

X_scaled.shape
# Out:
# (284292, 12)

# %%
ls
# Out:
# Classification/  code/  Dimensionality_Reduction/  README.md
# Clustering/      Data/  LICENSE.txt                Sundarbands_gt.mat

# %%
y_data = loadmat('Sundarbands_gt.mat')['gt']
y_data.shape
# Out:
# (954, 298)

# %%
# Visualize Groundtruth

ep.plot_bands(y_data, cmap=ListedColormap(['darkgreen', 'green', 'black', '#CA6F1E', 'navy', 'forestgreen']))
plt.show()

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_data.ravel(), test_size=0.30, stratify = y_data.ravel())

print(f'X_train Shape: {X_train.shape}\nX_test Shape: {X_test.shape}\ny_train Shape: {y_train.shape}\ny_test Shape:{y_test.shape}')
# Out:
# X_train Shape: (199004, 12)
# X_test Shape: (85288, 12)
# y_train Shape: (199004,)
# y_test Shape:(85288,)

# %% [markdown]
# # K-Nearest Neighbor Classifier (K-NNC)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, y_train)

knn_pred = knn.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, knn_pred)*100}")
# Out:
# Accuracy: 98.99868680236375

# %%
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     16222
#            1       1.00      1.00      1.00     23570
#            2       1.00      1.00      1.00      6095
#            3       0.99      0.99      0.99     16790
#            4       1.00      0.99      0.99     13545
#            5       0.98      0.95      0.97      9066
#
#     accuracy                           0.99     85288
#    macro avg       0.99      0.99      0.99     85288
# weighted avg       0.99      0.99      0.99     85288

# %%
# Visualize Classification Map of K-NNC

ep.plot_bands(knn.predict(X_scaled).reshape((954, 298)), 
              cmap=ListedColormap(['darkgreen', 'green', 'black', 
                                   '#CA6F1E', 'navy', 'forestgreen']))
plt.show()

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC

svm = SVC(C=3.0, kernel='rbf', degree=6, cache_size=1024)
svm.fit(X_train, y_train)
# Out:
# SVC(C=3.0, cache_size=1024, degree=6)

# %%
svm_pred = svm.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, svm_pred)*100}")
# Out:
# Accuracy: 99.88509520682862

# %%
print(classification_report(y_test, svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     16222
#            1       1.00      1.00      1.00     23570
#            2       1.00      1.00      1.00      6095
#            3       1.00      1.00      1.00     16790
#            4       1.00      1.00      1.00     13545
#            5       1.00      1.00      1.00      9066
#
#     accuracy                           1.00     85288
#    macro avg       1.00      1.00      1.00     85288
# weighted avg       1.00      1.00      1.00     85288

# %%
# Visualize Classification Map of SVM

ep.plot_bands(svm.predict(X_scaled).reshape((954, 298)), 
              cmap=ListedColormap(['darkgreen', 'green', 'black', 
                                   '#CA6F1E', 'navy', 'forestgreen']))
plt.show()

# %% [markdown]
# # Light BGM

# %%
pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lightgbm
#   Downloading lightgbm-4.4.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 7.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /home/kl/.local/lib/python3.10/site-packages (from lightgbm) (1.14.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/kl/.local/lib/python3.10/site-packages (from lightgbm) (1.25.2)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm as lgb

d_train = lgb.Dataset(X_train, label=y_train)

params={}
params['learning_rate']=0.03
params['boosting_type']='gbdt' #GradientBoostingDecisionTree
params['objective']='multiclass' #Multi-class target feature
params['metric']='multi_logloss' #metric for multi-class
params['max_depth']=15
params['num_class']=6 #no.of unique values in the target class not inclusive of the end value

clf = lgb.train(params, d_train, 100)
# Out:
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=15) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32768) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Warning] Provided parameters constrain tree depth (max_depth=15) without explicitly setting 'num_leaves'. This can lead to underfitting. To resolve this warning, pass 'num_leaves' (<=32768) in params. Alternatively, pass (max_depth=-1) and just use 'num_leaves' to constrain model complexity.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002981 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3060
# [LightGBM] [Info] Number of data points in the train set: 199004, number of used features: 12
# [LightGBM] [Info] Start training from score -1.659694
# [LightGBM] [Info] Start training from score -1.286046
# [LightGBM] [Info] Start training from score -2.638465
# [LightGBM] [Info] Start training from score -1.625235
# [LightGBM] [Info] Start training from score -1.840073
# [LightGBM] [Info] Start training from score -2.241496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
lgb_predictions = clf.predict(X_test)

# %%
print(lgb_predictions[1], np.argmax(lgb_predictions[1]))
# Out:
# [0.01326435 0.94884509 0.00530647 0.01346382 0.01118449 0.00793578] 1

# %%
# lbg_pred = [np.argmax(x) for x in lgb_predictions]
# np.array(lbg_pred).shape

lgb_pred = np.argmax(lgb_predictions, axis=1)
lgb_pred.shape
# Out:
# (85288,)

# %%
print(f"Accuracy: {accuracy_score(y_test, lgb_pred)*100}")
# Out:
# Accuracy: 99.00337679392177

# %%
print(classification_report(y_test, lgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     16222
#            1       1.00      1.00      1.00     23570
#            2       1.00      1.00      1.00      6095
#            3       0.99      0.99      0.99     16790
#            4       0.99      0.99      0.99     13545
#            5       0.97      0.97      0.97      9066
#
#     accuracy                           0.99     85288
#    macro avg       0.99      0.99      0.99     85288
# weighted avg       0.99      0.99      0.99     85288

# %%
# Visualize Classification Map of LightGBM

ep.plot_bands(np.argmax(clf.predict(X_scaled), axis=1).reshape((954, 298)), 
              cmap=ListedColormap(['darkgreen', 'green', 'black', 
                                   '#CA6F1E', 'navy', 'forestgreen']))
plt.show()

# %% [markdown]
# ---
